# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek-M-B/DSA_Assignments/blob/main/Practice1_Abhishek_M_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ASSIGNMENT 1 [*Data* *Types* *And* *Operators*] - **ABHISHEK** **M** **B**

# %% [markdown]
# 1. What is the output of print(type(5 + 5.0))?

# %%
print(type(5 + 5.0))
# Out:
# <class 'float'>

# %% [markdown]
# 2. Print the result of str(5) + " apples"

# %%
print(str(5) + " apples")
# Out:
# 5 apples

# %% [markdown]
# 3. Use len() to print the length of "Python Rocks!"

# %%
print(len("Python Rocks!"))
# Out:
# 13

# %% [markdown]
# 4. Add, subtract, multiply, and divide 15 and 4, and print all results

# %%
num1=15
num2=4

print(f"Addition : {num1+num2}")
print(f"Subtraction : {num1-num2}")
print(f"Multiply : {num1*num2}")
print(f"Division : {num1/num2}")
# Out:
# Addition : 19
# Subtraction : 11
# Multiply : 60
# Division : 3.75

# %% [markdown]
# 5. Find the floor division of 15 by 4

# %%
num1=15
num2=4
print(f"Floor division : {num1//num2}")
# Out:
# Floor division : 3

# %% [markdown]
# 6. Use modulo to find the remainder when 17 is divided by 5

# %%
num1=17
num2=5
print(f"Remainder : {num1%num2}")
# Out:
# Remainder : 2

# %% [markdown]
# 7. Raise 3 to the power of 4 and print

# %%
num1=3
num2=4
print(num1**num2)
# Out:
# 81

# %% [markdown]
# 8. Evaluate 10 + 2 * 5 and explain the output

# %%
result=10+2*5
print(result)
# Out:
# 20

# %% [markdown]
# 9. Use print() to show the result of 7 % 3 == 1

# %%
print(7%3==1)
# Out:
# True

# %% [markdown]
# 10. Store the result of 3 ** 2 + 1 in a variable and print its type

# %%
result=3**2+1
print(type(result))
# Out:
# <class 'int'>

# %% [markdown]
# 11. Use print() to check if 8 // 3 equals 2

# %%
print(8//3==2)
# Out:
# True

# %% [markdown]
# 12. Use print() to show if len("car") == 3

# %%
print(len("car")==3)
# Out:
# True

# %% [markdown]
# 13. Check if "Python" != "python" and print the result

# %%
print("Python" != "python")
# Out:
# True

# %% [markdown]
# 14. Compare the type of "10" with 10

# %%
t1=(type("10"))
t2=(type(10))
print(t1==t2)
# Out:
# False

# %% [markdown]
# 15. Check if None == False

# %%
print(None == False)
# Out:
# False

# %% [markdown]
# 16. Use print() to show whether 10 >= 10

# %%
print(10 >= 10)
# Out:
# True

# %% [markdown]
# 17. Use logical operators to check if a number is between 10 and 20

# %%
num=int(input("Enter the num: "))
check = (num>=10) and (num<=20)
print(check)
# Out:
# Enter the num: 15
# True

# %% [markdown]
# 18. Get the length of "1234567890" and check if it's even

# %%
num=len("1234567890")
if num%2==0:
  print("Even number")
else:
  print("Odd number")
# Out:
# Even number

# %% [markdown]
# 19. Use a string, check if it contains "@" and "." (email format)

# %%
email="abhishek@gmailcom"
if ("@" in email) and ("." in email):
    print("Is_present")

# %% [markdown]
# 20. Check whether the type of len("hello") is int

# %%
str1=len("hello")
print(type(str1)==int)
# Out:
# True
